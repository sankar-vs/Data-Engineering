# %%
#### @Author: Sankar
#### @Date: 2021-04-20 07:21:25
#### @Last Modified by: Sankar
#### @Last Modified time: 2021-04-20 07:26:09
#### @Title : Seaborn_Pointplot-1

# %%
##### Write a program to draw a point plot for sex against survived for a dataset given in url
##### https://github.com/mwaskom/seaborn-data/blob/master/titanic.csv

# %%
import seaborn as sb
import pandas as pd

# %%
df = pd.read_csv('E:/Practice/Data_Engineering/Seaborn/resources/titanic.csv')
sb.pointplot(x='sex',y='age', data=df, hue="sex",linestyle='-').set_title('Age vs Sex')
# Out:
# Text(0.5, 1.0, 'Age vs Sex')
