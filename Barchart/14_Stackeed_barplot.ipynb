# %%
#### @Author: Sankar
#### @Date: 2021-04-19 10:10:25
#### @Last Modified by: Sankar
#### @Last Modified time: 2021-04-19 10:17:09
#### @Title : Barchart_Python-14

# %%
#### Write a Python program to create a stacked bar plot with error bars.
#### Note: Use bottom to stack the women?s bars on top of the men?s bars.
#### Sample Data:
#### Means (men) = (22, 30, 35, 35, 26)
#### Means (women) = (25, 32, 30, 35, 29)
#### Men Standard deviation = (4, 3, 4, 1, 5)
#### Women Standard deviation = (3, 5, 2, 3, 3)

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
menMeans = (22, 30, 35, 35, 26)
womenMeans = (25, 32, 30, 35, 29)
menStd = (4, 3, 4, 1, 5)
womenStd = (3, 5, 2, 3, 3)
index = np.arange(len(menMeans))

p1 = plt.bar(index, menMeans, yerr=menStd, color='r')
p2 = plt.bar(index, womenMeans,bottom=menMeans, yerr=womenStd, color='y')

index = np.arange(len(menMeans)) 
plt.ylabel('Scores')
plt.xlabel('Groups')
plt.title('Scores by group and gender')
plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()
