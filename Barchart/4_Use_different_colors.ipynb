# %% [markdown]
# ### @Author: Sankar
# ### @Date: 2021-04-19 07:45:25
# ### @Last Modified by: Sankar
# ### @Last Modified time: 2021-04-19 07:50:09
# ### @Title : Barchart_Python-4

# %% [markdown]
# #### Write a Python programming to display a horizontal bar chart of the popularity of programming Languages. Use different color for each bar.
# #### Sample data:
# #### Programming languages: Java, Python, PHP, JavaScript, C#, C++
# #### Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
from matplotlib import pyplot as plt

# %%
languages = ["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
popularity =  [22.2, 17.6, 8.8, 8, 7.7, 6.7]
x_pos = [i for i, _ in enumerate(languages)]

plt.bar(x_pos, popularity, color=['red', 'black', 'green', 'blue', 'yellow', 'cyan'], edgecolor='black')

plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.title("Popularity of Programming Language")
plt.xticks(x_pos, languages)
# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
# Customize the minor grid
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
