# %%
#### @Author: Sankar
#### @Date: 2021-04-20 06:47:25
#### @Last Modified by: Sankar
#### @Last Modified time: 2021-04-20 06:55:09
#### @Title : Seaborn_Barplot-1

# %%
##### Write a program to draw bar plot of sex against survived for a dataset given in the url
##### https://github.com/mwaskom/seaborn-data/blob/master/titanic.csv

# %%
import pandas as pd
import seaborn as sb
import numpy as np

# %%
df = pd.read_csv('E:/Practice/Data_Engineering/Seaborn/Barplot/resources/titanic.csv')
sb.barplot(x='sex', y='age', data=df, estimator=np.std).set_title('Age vs Sex')
# Out:
# Text(0.5, 1.0, 'Age vs Sex')
