# %%
#### @Author: Sankar
#### @Date: 2021-04-20 07:37:25
#### @Last Modified by: Sankar
#### @Last Modified time: 2021-04-20 07:45:09
#### @Title : Seaborn_Violinplot-1

# %%
##### Write a program to draw a violin plot of sex against day for a given dataset
##### https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# %%
import seaborn as sb
import pandas as pd

# %%
df = pd.read_csv('E:/Practice/Data_Engineering/Seaborn/resources/tips.csv')
sb.violinplot(x='sex',y='tip', data=df).set_title('Sex vs Tips')
# Out:
# Text(0.5, 1.0, 'Sex vs Tips')
