# %%
#### @Author: Sankar
#### @Date: 2021-04-19 11:52:25
#### @Last Modified by: Sankar
#### @Last Modified time: 2021-04-19 11:59:09
#### @Title : Piechart_Python-3

# %%
#### Write a Python programming to create a pie chart with a title of the popularity of programming Languages.Make multiple wedges of the pie.
#### Sample data:
#### Programming languages: Java, Python, PHP, JavaScript, C#, C++
#### Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
from matplotlib import pyplot as plt

# %%
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popuratity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b"]
wedges = (0.1, 0, 0.1, 0.1, 0.1, 0.1)

plt.pie(popuratity, explode=wedges, labels=languages, colors=colors, autopct='%1.1f%%', shadow=True,startangle=140)

plt.axis('equal')
plt.title("PopularitY of Programming Language")
plt.show()
