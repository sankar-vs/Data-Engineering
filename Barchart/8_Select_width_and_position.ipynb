# %%
### @Author: Sankar
### @Date: 2021-04-19 08:12:25
### @Last Modified by: Sankar
### @Last Modified time: 2021-04-19 08:16:09
### @Title : Barchart_Python-8

# %%
#### Write a Python programming to display a bar chart of the popularity of programming Languages. Select the width of each bar and their positions.
#### Sample data:
#### Programming languages: Java, Python, PHP, JavaScript, C#, C++
#### Popularity: 22.2, 17.6, 8.8, 8, 7.7, 6.7

# %%
from matplotlib import pyplot as plt

# %%
languages = ["Java", "Python", "PHP", "JavaScript", "C#", "C++"]
popularity =  [22.2, 17.6, 8.8, 8, 7.7, 6.7]
x_pos = [0,5,3,1,4,7]
x_width = [0.1,0.2,0.5,1.1,0.2,0.3]

plt.bar(x_pos, popularity, color=(0.4, 0.6, 0.8, 1.0), edgecolor='blue', width = x_width)

plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.title("PopularitY of Programming Language")
plt.xticks(x_pos, languages)

plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')

plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
