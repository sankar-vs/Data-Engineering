# %%
#### @Author: Sankar
#### @Date: 2021-04-20 08:00:25
#### @Last Modified by: Sankar
#### @Last Modified time: 2021-04-20 08:05:09
#### @Title : Seaborn_Swarmplot-1

# %%
##### Write a program to draw a swarm plot of total bill against size for a given dataset
##### https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# %%
import seaborn as sb
import pandas as pd

# %%
df = pd.read_csv('E:/Practice/Data_Engineering/Seaborn/resources/tips.csv')
sb.swarmplot(x='size',y='total_bill', data=df).set_title('Total Bill against Size')
# Out:
# C:\Users\vssan\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 26.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Total Bill against Size')
