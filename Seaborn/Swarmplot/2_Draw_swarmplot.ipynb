# %%
#### @Author: Sankar
#### @Date: 2021-04-20 08:00:25
#### @Last Modified by: Sankar
#### @Last Modified time: 2021-04-20 08:05:09
#### @Title : Seaborn_Swarmplot-2

# %%
##### Write a program to draw swarm plot of “total bill” against day for a dataset given in url
##### https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# %%
import seaborn as sb
import pandas as pd

# %%
df = pd.read_csv('E:/Practice/Data_Engineering/Seaborn/resources/tips.csv')
sb.swarmplot(x='day',y='total_bill', data=df).set_title('Total Bill against day')
# Out:
# Text(0.5, 1.0, 'Total Bill against day')
