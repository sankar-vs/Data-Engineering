# %%
#### @Author: Sankar
#### @Date: 2021-04-20 07:46:25
#### @Last Modified by: Sankar
#### @Last Modified time: 2021-04-20 07:55:09
#### @Title : Seaborn_Boxplot-1

# %%
##### Write a program to draw box plot of life expectancy by continent for a data set given in a url
##### https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv

# %%
import seaborn as sb
import pandas as pd

# %%
df = pd.read_csv('E:/Practice/Data_Engineering/Seaborn/resources/gapminder.csv')
sb.boxplot(x='continent',y='lifeExp', data=df).set_title('Life Expectancy by Continent')
# Out:
# Text(0.5, 1.0, 'Life Expectancy by Continent')
