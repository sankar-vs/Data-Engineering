# %%
#### @Author: Sankar
#### @Date: 2021-04-20 07:17:25
#### @Last Modified by: Sankar
#### @Last Modified time: 2021-04-20 07:20:09
#### @Title : Seaborn_Barplot-2

# %%
##### Write a program to draw a barplot to show count for a deck for a dataset given in the url
##### https://github.com/mwaskom/seaborn-data/blob/master/titanic.csv

# %%
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv('E:/Practice/Data_Engineering/Seaborn/resources/titanic.csv')
sb.countplot(x='sex', data=df).set_title('Count of Sex')
# Out:
# Text(0.5, 1.0, 'Count of Sex')
