# %%
#### @Author: Sankar
#### @Date: 2021-04-20 07:42:25
#### @Last Modified by: Sankar
#### @Last Modified time: 2021-04-20 07:45:09
#### @Title : Seaborn_Violinplot-2

# %%
##### Write a program to draw a violin plot of “species” against “sepal length” for a dataset given in a url
##### https://github.com/mwaskom/seaborn-data/blob/master/iris.csv

# %%
import seaborn as sb
import pandas as pd

# %%
df = pd.read_csv('E:/Practice/Data_Engineering/Seaborn/resources/iris.csv')
sb.violinplot(x='species',y='sepal_length', data=df).set_title('Species vs Sepal_Length')
# Out:
# Text(0.5, 1.0, 'Species vs Sepal_Length')
