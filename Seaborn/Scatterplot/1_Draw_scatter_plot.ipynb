# %%
#### @Author: Sankar
#### @Date: 2021-04-20 07:30:25
#### @Last Modified by: Sankar
#### @Last Modified time: 2021-04-20 07:35:09
#### @Title : Seaborn_Scatterplot-1

# %%
##### Write a program to draw a scatter plot of “day” against “total bill” for a dataset given in a url
##### https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# %%
import seaborn as sb
import pandas as pd

# %%
df = pd.read_csv('E:/Practice/Data_Engineering/Seaborn/resources/tips.csv')
sb.scatterplot(x='day',y='total_bill', data=df).set_title('Day vs Total_Bill')
# Out:
# Text(0.5, 1.0, 'Day vs Total_Bill')
